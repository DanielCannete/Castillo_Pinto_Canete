# %%
import matplotlib.pyplot as plt

labels = 'Producción de madera (83%)', 'Ganado no producido-Carbono capturado(3%)', 'Biodiversidad(9%)','Recursos de investigación(5%)'
sizes = [83, 3, 9, 5]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7aeb9b4d9a80>,
# ...
#  [Text(-0.9468162003458401, 0.5599456069679145, 'Producción de madera (83%)'),
#   Text(0.6182916183185512, -0.9097886978397935, 'Ganado no producido-Carbono capturado(3%)'),
#   Text(0.9097885712083761, -0.6182918046510254, 'Biodiversidad(9%)'),
#   Text(1.0864571601546607, -0.17207800309356905, 'Recursos de investigación(5%)')])
